# %% [markdown]
# # Introduction
#
# Welcome to your Amazon SageMaker notebook instance!
#
# This is a fully managed AWS environment that provides you a Jupyter Notebook to work with data.  To learn more about Amazon SageMake notebook instances, check out our [documentation](https://docs.aws.amazon.com/sagemaker/latest/dg/nbi.html).
#
# ## Summary
#
# We're looking to build a linear model to help with our Wild Rydes machine learning challenge.  A linear model is a supervised learning algorithm used to solving either classification or regression problems.  This notebook will help us to:
#
# 1. Setup serverless querying of data in S3 via [Amazon Athena](https://aws.amazon.com/athena/).
# 2. Prepare dataframes using [pandas](https://pandas.pydata.org/) and [numpy](https://numpy.org).
# 3. Build and train a machline learning model via the [Amazon SageMaker Python SDK](https://docs.aws.amazon.com/sagemaker/latest/dg/frameworks.html).
#
# To get started, let's input the name of the S3 bucket you created earlier in this workshop:

# %%
# ACTION: provide the data bucket you are using for this workshop
data_bucket = ''

# %% [markdown]
# We'll now use your S3 bucket to help interact with data.
#
# ### Objective: Enable serverless querying via Amazon Athena
#
# The next thing we'll do is install [PyAthena](https://pypi.org/project/PyAthena/) so we can use Amazon Athena.  Athena is a serverless query solution that will let use query data in S3 as if it were loaded into a database.  Run the next cell to install the package we need to get started with Athena.

# %%
# %%capture 
## above line surpresses installation output from this cell


## Install PyAthena to enable our notebook instance to use Athena
import sys
# !{sys.executable} -m pip install PyAthena

# %% [markdown]
# PyAthena gives us the ability to connect to Amazon Athena so we can start defining data objects in S3.  In the next cell, let's go ahead and load up the PyAthena, pandas, and boto3 library so we can start sending SQL queries to Athena.  Our first query will be to establish a serverless database for use in this workshop.

# %%
# load necessary libraries
from pyathena import connect
import pandas as pd
import boto3

# create place to store athena query results
athena_query_results = ("s3://%s/results/" % data_bucket)

# establish athena connection in the same region as our S3 bucket
data_bucket_region = boto3.client('s3').get_bucket_location(Bucket=data_bucket)['LocationConstraint']

conn = connect(s3_staging_dir=athena_query_results,
               region_name=data_bucket_region)

# create a serverless database
athena_database = "wildrydesworkshop"

sql_stmt_create_db = ("CREATE DATABASE IF NOT EXISTS %s" % athena_database)

pd.read_sql(sql_stmt_create_db, conn)

# list all databases to confirm our new database exists
pd.read_sql(("SHOW DATABASES LIKE '%s'" % athena_database), conn)
# Out:
#        database_name
# 0  wildrydesworkshop

# %% [markdown]
# We now have a serverless database that we can create external tables in.  External tables are objects where the data is stored away from the related compute service.  In this case, Athena is our query service and our data is stored separately in S3.
#
# In the Data Processing portion of this workshop, we processed some telemetry data and saved the results in S3.  Let's go ahead and create an external table of this data so we can query in later.

# %%
# create an external table based on the process ride telemetry data
processed_table = "ridetelemetry"

# drop the table if we're rerunning this cell
pd.read_sql("DROP TABLE IF EXISTS %s.%s" % (athena_database, processed_table),conn)

# create an external table based on the schema output from our data procressing module
sql_stmt_create_tb = """
CREATE EXTERNAL TABLE IF NOT EXISTS %s.%s (
 distance double
,healthpoints bigint
,latitude double
,longitude double
,magicpoints bigint
,name string
,statustime string
,groundstation string
,heavy_utilization bigint
)
ROW FORMAT SERDE 'org.apache.hadoop.hive.serde2.lazy.LazySimpleSerDe'
WITH SERDEPROPERTIES (
"field.delim" = ","
,"skip.header.line.count" = "1"
)
LOCATION 's3://%s/processed/'
""" % (athena_database, processed_table, data_bucket)

pd.read_sql(sql_stmt_create_tb, conn)

# confirm that our new table exists
pd.read_sql(("SHOW TABLES IN %s" % athena_database), conn)
# Out:
#         tab_name
# 0  ridetelemetry
# 1        weather

# %% [markdown]
# We now have an external table in Athena based on our telemetry data.  That's great but want to know what's even better?  We can also make external tables of public datasets published to Amazon S3!  That means all the historical weather data that NOAA stores in S3 can also be an external table for us to use.  Let's go ahead and create an external table of it.

# %%
# create an external table based on NOAA's weather files
weather_table = "weather"

# drop the table if we're rerunning this cell
pd.read_sql("DROP TABLE IF EXISTS %s.%s" % (athena_database, weather_table),conn)

# create an external table based on the data schema @ https://docs.opendata.aws/noaa-ghcn-pds/readme.html
# 'year_date' isn't expressed as a typical datetime type, so we'll worry about it later.
sql_stmt_create_tb = """
CREATE EXTERNAL TABLE IF NOT EXISTS %s.%s (
 id string
,year_date string
,element string
,data_value double
,m_flag string
,q_flag string
,s_flag string
,obs_time string
)
ROW FORMAT SERDE 'org.apache.hadoop.hive.serde2.lazy.LazySimpleSerDe'
WITH SERDEPROPERTIES (
"field.delim" = ","
)
LOCATION 's3://noaa-ghcn-pds/csv/'
""" % (athena_database, weather_table)

# send the create table query statement to our Athena connection
pd.read_sql(sql_stmt_create_tb, conn)

# confirm that our new table exists
pd.read_sql(("SHOW TABLES IN %s" % athena_database), conn)
# Out:
#         tab_name
# 0  ridetelemetry
# 1        weather

# %% [markdown]
# ### Checkpoint reached: Enabled querying data in S3
#
# We now have the ability to query both our telemetry data and NOAA data directly from S3 via Athena.  Let's run a couple queries to see how large these tables are.

# %%
# count telemetry records
pd.read_sql("""
SELECT '%s' as tablename, COUNT(*) records FROM  %s.%s
UNION ALL
SELECT '%s' as tablename, COUNT(*) records FROM  %s.%s
""" % (processed_table, athena_database, processed_table,
       weather_table, athena_database, weather_table
      ), conn)
# Out:
#        tablename     records
# 0  ridetelemetry       19995
# 1        weather  2913004224

# %% [markdown]
# ### Objective: Create dataframe objects for our linear model
#
# Our telemetry data looks pretty managable but check out the size of the weather data!  We probably don't need the vast majority of that.  Let's setup our telemetry data as a pandas dataframe so can we figure out how much weather data we really need.

# %%
# create a Python panda dataframe with our processed ride telemetry data
df_telemetry = pd.read_sql("SELECT * FROM %s.%s" % (athena_database, processed_table), conn)

# we need to describe the datetime format in order for our telemetry data to use
# a datatime data type.  Let's update our 'statustime' field to a datetime data type.
df_telemetry['statustime'] = pd.to_datetime(df_telemetry['statustime'], format='%Y-%m-%d %H:%M:%S.%f')

# let's add a date field that doesn't have time so we can easily join to weather data later
df_telemetry['year_date'] = pd.to_datetime(df_telemetry['statustime'].dt.strftime('%Y-%m-%d'))

# here's the descriptive summary of the telemetry dataframe
df_telemetry.describe(include='all')
# Out:
#             distance  healthpoints      latitude     longitude   magicpoints  \
# count   19995.000000  19995.000000  19995.000000  19995.000000  19995.000000
# unique           NaN           NaN           NaN           NaN           NaN
# top              NaN           NaN           NaN           NaN           NaN
# freq             NaN           NaN           NaN           NaN           NaN
# first            NaN           NaN           NaN           NaN           NaN
# last             NaN           NaN           NaN           NaN           NaN
# mean       29.990560    299.409702     38.251849    -75.344124    348.040760
# std         0.575566      5.750261      1.441605      0.775382    358.767293
# min        29.000009    290.000000     35.755304    -76.671848    290.000000
# 25%        29.494163    294.000000     37.003521    -76.017281    295.000000
# 50%        29.984823    299.000000     38.251744    -75.351873    300.000000
# 75%        30.488369    304.000000     39.500487    -74.674651    305.000000
# max        30.999964    309.000000     40.748660    -73.985467   3090.000000
#
#              name           statustime groundstation  heavy_utilization  \
# count       19995                19995         19995       19995.000000
# unique          1                19995             2                NaN
# top     Shadowfax  2018-09-02 06:03:12   USW00094789                NaN
# freq        19995                    1         18914                NaN
# first         NaN  2017-12-30 18:04:50           NaN                NaN
# last          NaN  2018-12-30 17:11:21           NaN                NaN
# mean          NaN                  NaN           NaN           0.018055
# std           NaN                  NaN           NaN           0.133152
# min           NaN                  NaN           NaN           0.000000
# 25%           NaN                  NaN           NaN           0.000000
# 50%           NaN                  NaN           NaN           0.000000
# 75%           NaN                  NaN           NaN           0.000000
# max           NaN                  NaN           NaN           1.000000
#
#                   year_date
# count                 19995
# unique                  366
# top     2018-09-26 00:00:00
# freq                     74
# first   2017-12-30 00:00:00
# last    2018-12-30 00:00:00
# mean                    NaN
# std                     NaN
# min                     NaN
# 25%                     NaN
# 50%                     NaN
# 75%                     NaN
# max                     NaN

# %% [markdown]
# Thinking about how to filter down our weather data, the above telemetry dataframe description tells us:
# - There are only a couple groundstation ids
# - Our ride dates start in 2017
#
# Keeping those facts in mind, let's work on creating our weather dataframe next.

# %%
# first let's get our interested ground stations ids from our telemetry data
unique_gs = tuple(df_telemetry.groundstation.unique())

# weather data goes back far in time.  let's only grab data for the years we need
start_year = pd.to_datetime(df_telemetry.statustime.min()).year

# let's create our query statement
weather_query = """
SELECT * FROM %s.%s
WHERE q_flag = ''
AND id IN %s
AND year(date_parse(year_date, '%%Y%%m%%d')) >= %s
""" % (athena_database, weather_table, unique_gs, start_year)

# now we'll pass the query to Athena to get back our interested weather data.
# Athena will scan over 2 billion records (90+ GB) in just over 30 seconds.
df_weather = pd.read_sql(weather_query, conn)

# we want to make sure the 'data_value' field is a numeric column
df_weather['data_value'] = pd.to_numeric(df_weather['data_value'])

# let's also make sure 'year_date' is a proper date field
df_weather['year_date'] = pd.to_datetime(df_weather['year_date'])

#
df_weather.describe(include='all')
# Out:
#                  id            year_date element    data_value m_flag q_flag  \
# count         22656                22656   22656  22656.000000  22656  22656
# unique            2                 1049      21           NaN      3      1
# top     USW00094789  2017-02-09 00:00:00    TMAX           NaN
# freq          12212                   28    2098           NaN  21258  22656
# first           NaN  2017-01-01 00:00:00     NaN           NaN    NaN    NaN
# last            NaN  2019-11-15 00:00:00     NaN           NaN    NaN    NaN
# mean            NaN                  NaN     NaN     89.298729    NaN    NaN
# std             NaN                  NaN     NaN    101.192932    NaN    NaN
# min             NaN                  NaN     NaN   -166.000000    NaN    NaN
# 25%             NaN                  NaN     NaN      0.000000    NaN    NaN
# 50%             NaN                  NaN     NaN     58.000000    NaN    NaN
# 75%             NaN                  NaN     NaN    152.000000    NaN    NaN
# max             NaN                  NaN     NaN   1509.000000    NaN    NaN
#
#        s_flag obs_time
# count   22656    22656
# unique      3        2
# top         W
# freq    21040    14264
# first     NaN      NaN
# last      NaN      NaN
# mean      NaN      NaN
# std       NaN      NaN
# min       NaN      NaN
# 25%       NaN      NaN
# 50%       NaN      NaN
# 75%       NaN      NaN
# max       NaN      NaN

# %%
# we want some interesting weather facts as features, so let's pivot the data
df_weather_pivot = pd.DataFrame(df_weather, columns = ['id','year_date','element', 'data_value']) \
    .query('element in ("TMIN", "TMAX", "PRCP")') \
    .pivot_table(index=['id','year_date'], columns='element', values='data_value') \
    .reset_index()

# element definitions from https://docs.opendata.aws/noaa-ghcn-pds/readme.html
## PRCP = Precipitation (tenths of mm)
## TMAX = Maximum temperature (tenths of degrees C)
## TMIN = Minimum temperature (tenths of degrees C)

# now our weather data looks like this
df_weather_pivot.describe(include='all')
# Out:
# element           id            year_date         PRCP         TMAX  \
# count           2098                 2098  2098.000000  2098.000000
# unique             2                 1049          NaN          NaN
# top      USW00094728  2019-05-13 00:00:00          NaN          NaN
# freq            1049                    2          NaN          NaN
# first            NaN  2017-01-01 00:00:00          NaN          NaN
# last             NaN  2019-11-15 00:00:00          NaN          NaN
# mean             NaN                  NaN    36.084366   173.694948
# std              NaN                  NaN    87.374648    98.788795
# min              NaN                  NaN     0.000000  -105.000000
# 25%              NaN                  NaN     0.000000    94.000000
# 50%              NaN                  NaN     0.000000   183.000000
# 75%              NaN                  NaN    20.000000   261.000000
# max              NaN                  NaN   770.000000   372.000000
#
# element         TMIN
# count    2098.000000
# unique           NaN
# top              NaN
# freq             NaN
# first            NaN
# last             NaN
# mean       96.314585
# std        92.957829
# min      -166.000000
# 25%        22.000000
# 50%       106.000000
# 75%       183.000000
# max       278.000000

# %% [markdown]
# ### Checkpoint reached: created dataframes as inputs into our linear model
#
# We crafted two dataframes: ride telemetry & pivoted weather facts.  Now let's merge them into a single dataframe so we can start preparing our model.

# %%
# Let's merge our telemetry data with weather so we can include weather elements as model features
merge_df = pd.merge(df_telemetry, df_weather_pivot
                     , left_on=['groundstation','year_date']
                     , right_on=['id', 'year_date']
                     , how='left'
                    )

# %% [markdown]
# ### Objective: Pre-Processing the Data
# Now that we have data ready for modeling, let's shape it into inputs for our model.
#
# Our linear learner is expecting numpy arrays.  We'll first load the data into numpy arrays, and randomly split it into train set and test set with a 90/10 split.

# %%
import numpy as np
import os

processed_subdir = "standardized"
folder = "/home/ec2-user/SageMaker/"
train_features_file = os.path.join(folder, processed_subdir, "train/csv/features.csv")
train_labels_file = os.path.join(folder, processed_subdir, "train/csv/labels.csv")
test_features_file = os.path.join(folder, processed_subdir, "test/csv/features.csv")
test_labels_file = os.path.join(folder, processed_subdir, "test/csv/labels.csv")

raw = merge_df[['distance','healthpoints','magicpoints','TMIN','TMAX','PRCP','heavy_utilization']].to_numpy(dtype=np.float32)

# split into train/test with a 90/10 split
np.random.seed(0)
np.random.shuffle(raw)
train_size = int(0.9 * raw.shape[0])
train_features = raw[:train_size, :-1]
train_labels = raw[:train_size, -1]
test_features = raw[train_size:, :-1]
test_labels = raw[train_size:, -1]

print('train_features shape = ', train_features.shape)
print('train_labels shape = ', train_labels.shape)
print('test_features shape = ', test_features.shape)
print('test_labels shape = ', test_labels.shape)
# Out:
# train_features shape =  (17995, 6)
# train_labels shape =  (17995,)
# test_features shape =  (2000, 6)
# test_labels shape =  (2000,)

# %% [markdown]
# Let's write the training data to Amazon S3 in recordio-protobuf format.  This allows us to persist the data in case we need to return to this exact training set later.
#
# We first create an io buffer wrapping the data, next we upload it to Amazon S3. Notice that the choice of bucket and prefix should change for different users and different datasets.

# %%
import sagemaker.amazon.common as smac
import io

train_prefix = 'train'
key = 'recordio-pb-data'

buf = io.BytesIO()
smac.write_numpy_to_dense_tensor(buf, train_features, train_labels)
buf.seek(0)

boto3.resource('s3').Bucket(data_bucket).Object(os.path.join(train_prefix, key)).upload_fileobj(buf)
s3_train_data = 's3://{}/{}/{}'.format(data_bucket, train_prefix, key)
print('uploaded training data location: {}'.format(s3_train_data))
# Out:
# uploaded training data location: s3://wildrydes-ml-mod1-1-databucket-976964760667/train/recordio-pb-data

# %% [markdown]
# We should save our testing dataset to S3, too. This way we can evaluate the performance of the model from the training logs alongside the actual test data.

# %%
test_prefix = 'test'

buf = io.BytesIO()
smac.write_numpy_to_dense_tensor(buf, test_features, test_labels)
buf.seek(0)

boto3.resource('s3').Bucket(data_bucket).Object(os.path.join(test_prefix, key)).upload_fileobj(buf)
s3_test_data = 's3://{}/{}/{}'.format(data_bucket, test_prefix, key)
print('uploaded test data location: {}'.format(s3_test_data))
# Out:
# uploaded test data location: s3://wildrydes-ml-mod1-1-databucket-976964760667/test/recordio-pb-data

# %% [markdown]
# ### Checkpoint reached: data is ready for our linear learner model
#
# ### Objective: build and train our linear learner model
#
# We take a moment to explain at a high level, how Machine Learning training and prediction works in Amazon SageMaker. First, we need to train a model. This is a process that given a labeled dataset and hyper-parameters guiding the training process,  outputs a model. Once the training is done, we set up what is called an **endpoint**. An endpoint is a web service that given a request containing an unlabeled data point, or mini-batch of data points, returns a prediction(s).
#
# In Amazon SageMaker the training is done via an object called an **estimator**. When setting up the estimator we specify the location (in Amazon S3) of the training data, the path (again in Amazon S3) to the output directory where the model will be serialized, generic hyper-parameters such as the machine type to use during the training process, and specific hyper-parameters such as the index type, etc. Once the estimator is initialized, we can call its **fit** method in order to do the actual training.
#
# Now that we are ready for training, we start with a convenience function that starts a training job.

# %%
import matplotlib.pyplot as plt

import sagemaker
from sagemaker import get_execution_role
from sagemaker.predictor import csv_serializer, json_deserializer
from sagemaker.amazon.amazon_estimator import get_image_uri


def trained_estimator_from_hyperparams(s3_train_data, hyperparams, output_path, s3_test_data=None):
    """
    Create an Estimator from the given hyperparams, fit to training data, 
    and return a deployed predictor
    
    """
    # set up the estimator
    linear = sagemaker.estimator.Estimator(get_image_uri(boto3.Session().region_name, "linear-learner"),
        get_execution_role(),
        train_instance_count=1,
        train_instance_type='ml.m5.2xlarge',
        output_path=output_path,
        sagemaker_session=sagemaker.Session())
    linear.set_hyperparameters(**hyperparams)
    
    # train a model. fit_input contains the locations of the train and test data
    fit_input = {'train': s3_train_data}
    if s3_test_data is not None:
        fit_input['test'] = s3_test_data
    linear.fit(fit_input)
    return linear

# %% [markdown]
# Now, we run the actual training job. For now, we stick to default parameters.

# %%
import math

hyperparams = {
    'feature_dim': int(train_features.shape[1]),
    'mini_batch_size': int(0.1 * train_features.shape[0]),
    'predictor_type': 'binary_classifier' 
}

output_path = 's3://' + data_bucket
linear_estimator = trained_estimator_from_hyperparams(s3_train_data, hyperparams, output_path, 
                                                   s3_test_data=s3_test_data)
# Out:
# 2019-11-22 01:13:01 Starting - Starting the training job...
# 2019-11-22 01:13:03 Starting - Launching requested ML instances......
# 2019-11-22 01:14:04 Starting - Preparing the instances for training...
# 2019-11-22 01:14:52 Downloading - Downloading input data..
# 2019-11-22 01:15:28 Training - Training image download completed. Training in progress.
# 2019-11-22 01:15:28 Uploading - Uploading generated training model
# 2019-11-22 01:15:28 Completed - Training job completed
# Docker entrypoint called with argument(s): train
# [11/22/2019 01:15:17 INFO 139974246963008] Reading default configuration from /opt/amazon/lib/python2.7/site-packages/algorithm/resources/default-input.json: {u'loss_insensitivity': u'0.01', u'epochs': u'15', u'feature_dim': u'auto', u'init_bias': u'0.0', u'lr_scheduler_factor': u'auto', u'num_calibration_samples': u'10000000', u'accuracy_top_k': u'3', u'_num_kv_servers': u'auto', u'use_bias': u'true', u'num_point_for_scaler': u'10000', u'_log_level': u'info', u'quantile': u'0.5', u'bias_lr_mult': u'auto', u'lr_scheduler_step': u'auto', u'init_method': u'uniform', u'init_sigma': u'0.01', u'lr_scheduler_minimum_lr': u'auto', u'target_recall': u'0.8', u'num_models': u'auto', u'early_stopping_patience': u'3', u'momentum': u'auto', u'unbias_label': u'auto', u'wd': u'auto', u'optimizer': u'auto', u'_tuning_objective_metric': u'', u'early_stopping_tolerance': u'0.001', u'learning_rate': u'auto', u'_kvstore': u'auto', u'normalize_data': u'true', u'binary_classifier_model_selection_criteria': u'accuracy', u'use_lr_scheduler': u'true', u'target_precision': u'0.8', u'unbias_data': u'auto', u'init_scale': u'0.07', u'bias_wd_mult': u'auto', u'f_beta': u'1.0', u'mini_batch_size': u'1000', u'huber_delta': u'1.0', u'num_classes': u'1', u'beta_1': u'auto', u'loss': u'auto', u'beta_2': u'auto', u'_enable_profiler': u'false', u'normalize_label': u'auto', u'_num_gpus': u'auto', u'balance_multiclass_weights': u'false', u'positive_example_weight_mult': u'1.0', u'l1': u'auto', u'margin': u'1.0'}
# [11/22/2019 01:15:17 INFO 139974246963008] Reading provided configuration from /opt/ml/input/config/hyperparameters.json: {u'feature_dim': u'6', u'mini_batch_size': u'1799', u'predictor_type': u'binary_classifier'}
# [11/22/2019 01:15:17 INFO 139974246963008] Final configuration: {u'loss_insensitivity': u'0.01', u'epochs': u'15', u'feature_dim': u'6', u'init_bias': u'0.0', u'lr_scheduler_factor': u'auto', u'num_calibration_samples': u'10000000', u'accuracy_top_k': u'3', u'_num_kv_servers': u'auto', u'use_bias': u'true', u'num_point_for_scaler': u'10000', u'_log_level': u'info', u'quantile': u'0.5', u'bias_lr_mult': u'auto', u'lr_scheduler_step': u'auto', u'init_method': u'uniform', u'init_sigma': u'0.01', u'lr_scheduler_minimum_lr': u'auto', u'target_recall': u'0.8', u'num_models': u'auto', u'early_stopping_patience': u'3', u'momentum': u'auto', u'unbias_label': u'auto', u'wd': u'auto', u'optimizer': u'auto', u'_tuning_objective_metric': u'', u'early_stopping_tolerance': u'0.001', u'learning_rate': u'auto', u'_kvstore': u'auto', u'normalize_data': u'true', u'binary_classifier_model_selection_criteria': u'accuracy', u'use_lr_scheduler': u'true', u'target_precision': u'0.8', u'unbias_data': u'auto', u'init_scale': u'0.07', u'bias_wd_mult': u'auto', u'f_beta': u'1.0', u'mini_batch_size': u'1799', u'huber_delta': u'1.0', u'num_classes': u'1', u'predictor_type': u'binary_classifier', u'beta_1': u'auto', u'loss': u'auto', u'beta_2': u'auto', u'_enable_profiler': u'false', u'normalize_label': u'auto', u'_num_gpus': u'auto', u'balance_multiclass_weights': u'false', u'positive_example_weight_mult': u'1.0', u'l1': u'auto', u'margin': u'1.0'}
# [11/22/2019 01:15:17 WARNING 139974246963008] Loggers have already been setup.
# Process 1 is a worker.
# [11/22/2019 01:15:17 INFO 139974246963008] Using default worker.
# [2019-11-22 01:15:17.928] [tensorio] [warning] TensorIO is already initialized; ignoring the initialization routine.
# [2019-11-22 01:15:17.945] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 0, "duration": 21, "num_examples": 1, "num_bytes": 122332}
# [11/22/2019 01:15:17 INFO 139974246963008] Create Store: local
# [2019-11-22 01:15:17.971] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 1, "duration": 25, "num_examples": 6, "num_bytes": 733992}
# [11/22/2019 01:15:17 INFO 139974246963008] Scaler algorithm parameters
#  <algorithm.scaler.ScalerAlgorithmStable object at 0x7f4df4f271d0>
# [11/22/2019 01:15:17 INFO 139974246963008] Scaling model computed with parameters:
#  {'stdev_weight':
# [  0.573011    5.7238054 339.688      95.87667    98.03588    86.48768  ]
# <NDArray 6 @cpu(0)>, 'stdev_label': None, 'mean_label': None, 'mean_weight':
# [ 29.99421  299.44904  342.9107    88.13026  163.49231   39.686676]
# <NDArray 6 @cpu(0)>}
# [11/22/2019 01:15:18 INFO 139974246963008] nvidia-smi took: 0.0251140594482 secs to identify 0 gpus
# [11/22/2019 01:15:18 INFO 139974246963008] Number of GPUs being used: 0
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 6, "sum": 6.0, "min": 6}, "Number of Batches Since Last Reset": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Number of Records Since Last Reset": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Total Batches Seen": {"count": 1, "max": 7, "sum": 7.0, "min": 7}, "Total Records Seen": {"count": 1, "max": 12593, "sum": 12593.0, "min": 12593}, "Max Records Seen Between Resets": {"count": 1, "max": 10794, "sum": 10794.0, "min": 10794}, "Reset Count": {"count": 1, "max": 2, "sum": 2.0, "min": 2}}, "EndTime": 1574385318.05285, "Dimensions": {"Host": "algo-1", "Meta": "init_train_data_iter", "Operation": "training", "Algorithm": "Linear Learner"}, "StartTime": 1574385318.052819}
#
# [2019-11-22 01:15:18.272] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 3, "duration": 219, "num_examples": 11, "num_bytes": 1223660}
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.5866317333414397, "sum": 0.5866317333414397, "min": 0.5866317333414397}}, "EndTime": 1574385318.272794, "Dimensions": {"model": 0, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1574385318.272734}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.5990755022864265, "sum": 0.5990755022864265, "min": 0.5990755022864265}}, "EndTime": 1574385318.272886, "Dimensions": {"model": 1, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1574385318.272857}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.5968591152528314, "sum": 0.5968591152528314, "min": 0.5968591152528314}}, "EndTime": 1574385318.272937, "Dimensions": {"model": 2, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1574385318.272926}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.5942120927913511, "sum": 0.5942120927913511, "min": 0.5942120927913511}}, "EndTime": 1574385318.272985, "Dimensions": {"model": 3, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1574385318.272973}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.13713853548738014, "sum": 0.13713853548738014, "min": 0.13713853548738014}}, "EndTime": 1574385318.273027, "Dimensions": {"model": 4, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1574385318.273017}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0

#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.18890584762259416, "sum": 0.18890584762259416, "min": 0.18890584762259416}}, "EndTime": 1574385318.274083, "Dimensions": {"model": 31, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1574385318.274072}
#
# [11/22/2019 01:15:18 INFO 139974246963008] #quality_metric: host=algo-1, epoch=0, train binary_classification_cross_entropy_objective <loss>=0.586631733341
# [11/22/2019 01:15:18 INFO 139974246963008] #early_stopping_criteria_metric: host=algo-1, epoch=0, criteria=binary_classification_cross_entropy_objective, value=0.131052856912
# [11/22/2019 01:15:18 INFO 139974246963008] Epoch 0: Loss improved. Updating best model
# [11/22/2019 01:15:18 INFO 139974246963008] #progress_metric: host=algo-1, completed 6 % of epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 11, "sum": 11.0, "min": 11}, "Number of Batches Since Last Reset": {"count": 1, "max": 11, "sum": 11.0, "min": 11}, "Number of Records Since Last Reset": {"count": 1, "max": 17995, "sum": 17995.0, "min": 17995}, "Total Batches Seen": {"count": 1, "max": 18, "sum": 18.0, "min": 18}, "Total Records Seen": {"count": 1, "max": 30588, "sum": 30588.0, "min": 30588}, "Max Records Seen Between Resets": {"count": 1, "max": 17995, "sum": 17995.0, "min": 17995}, "Reset Count": {"count": 1, "max": 3, "sum": 3.0, "min": 3}}, "EndTime": 1574385318.277234, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1574385318.053014}
#
# [11/22/2019 01:15:18 INFO 139974246963008] #throughput_metric: host=algo-1, train throughput=80223.4845051 records/second
# [2019-11-22 01:15:18.454] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 5, "duration": 176, "num_examples": 11, "num_bytes": 1223660}
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.4022701346125452, "sum": 0.4022701346125452, "min": 0.4022701346125452}}, "EndTime": 1574385318.454269, "Dimensions": {"model": 0, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1574385318.454204}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.4124660150550219, "sum": 0.4124660150550219, "min": 0.4124660150550219}}, "EndTime": 1574385318.454344, "Dimensions": {"model": 1, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1574385318.45433}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.4117586620388063, "sum": 0.4117586620388063, "min": 0.4117586620388063}}, "EndTime": 1574385318.454401, "Dimensions": {"model": 2, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1574385318.454388}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.40827018903188406, "sum": 0.40827018903188406, "min": 0.40827018903188406}}, "EndTime": 1574385318.454445, "Dimensions": {"model": 3, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1574385318.454434}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.0017206924699822554, "sum": 0.0017206924699822554, "min": 0.0017206924699822554}}, "EndTime": 1574385318.454491, "Dimensions": {"model": 4, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1574385318.454479}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.0018107247193566026, "sum": 0.0018107247193566026, "min": 0.0018107247193566026}}, "EndTime": 1574385318.454536, "Dimensions": {"model": 5, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1574385318.454524}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.001716644575756215, "sum": 0.001716644575756215, "min": 0.001716644575756215}}, "EndTime": 1574385318.454583, "Dimensions": {"model": 6, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1574385318.454574}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.0014752089347754536, "sum": 0.0014752089347754536, "min": 0.0014752089347754536}}, "EndTime": 1574385318.454622, "Dimensions": {"model": 7, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1574385318.454615}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.4030376338905729, "sum": 0.4030376338905729, "min": 0.4030376338905729}}, "EndTime": 1574385318.454651, "Dimensions": {"model": 8, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1574385318.454643}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.4084483682612302, "sum": 0.4084483682612302, "min": 0.4084483682612302}}, "EndTime": 1574385318.454685, "Dimensions": {"model": 9, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1574385318.454678}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.4064399825260996, "sum": 0.4064399825260996, "min": 0.4064399825260996}}, "EndTime": 1574385318.454713, "Dimensions": {"model": 10, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1574385318.454707}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.3990173950534585, "sum": 0.3990173950534585, "min": 0.3990173950534585}}, "EndTime": 1574385318.454752, "Dimensions": {"model": 11, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1574385318.454742}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.0015454736134951615, "sum": 0.0015454736134951615, "min": 0.0015454736134951615}}, "EndTime": 1574385318.454797, "Dimensions": {"model": 12, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1574385318.454786}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.0016069455833286627, "sum": 0.0016069455833286627, "min": 0.0016069455833286627}}, "EndTime": 1574385318.454841, "Dimensions": {"model": 13, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1574385318.454833}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.0019243953094143149, "sum": 0.0019243953094143149, "min": 0.0019243953094143149}}, "EndTime": 1574385318.454885, "Dimensions": {"model": 14, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1574385318.454875}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.0016670434457716377, "sum": 0.0016670434457716377, "min": 0.0016670434457716377}}, "EndTime": 1574385318.454934, "Dimensions": {"model": 15, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1574385318.454922}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.4070142049402446, "sum": 0.4070142049402446, "min": 0.4070142049402446}}, "EndTime": 1574385318.454983, "Dimensions": {"model": 16, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1574385318.454971}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.4039147487807897, "sum": 0.4039147487807897, "min": 0.4039147487807897}}, "EndTime": 1574385318.455026, "Dimensions": {"model": 17, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1574385318.455015}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.4059835589813351, "sum": 0.4059835589813351, "min": 0.4059835589813351}}, "EndTime": 1574385318.455068, "Dimensions": {"model": 18, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1574385318.455056}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.4022521633383564, "sum": 0.4022521633383564, "min": 0.4022521633383564}}, "EndTime": 1574385318.455108, "Dimensions": {"model": 19, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1574385318.455097}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.10190893133989369, "sum": 0.10190893133989369, "min": 0.10190893133989369}}, "EndTime": 1574385318.455146, "Dimensions": {"model": 20, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1574385318.455134}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.10208950753076797, "sum": 0.10208950753076797, "min": 0.10208950753076797}}, "EndTime": 1574385318.455186, "Dimensions": {"model": 21, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1574385318.455175}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.1043894701497034, "sum": 0.1043894701497034, "min": 0.1043894701497034}}, "EndTime": 1574385318.455227, "Dimensions": {"model": 22, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1574385318.455216}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.10292071882653991, "sum": 0.10292071882653991, "min": 0.10292071882653991}}, "EndTime": 1574385318.455266, "Dimensions": {"model": 23, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1574385318.455257}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.4151098958514279, "sum": 0.4151098958514279, "min": 0.4151098958514279}}, "EndTime": 1574385318.455314, "Dimensions": {"model": 24, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1574385318.455302}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.41431980440522514, "sum": 0.41431980440522514, "min": 0.41431980440522514}}, "EndTime": 1574385318.455361, "Dimensions": {"model": 25, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1574385318.455349}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.414448989265955, "sum": 0.414448989265955, "min": 0.414448989265955}}, "EndTime": 1574385318.455409, "Dimensions": {"model": 26, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1574385318.455397}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.41456363629208065, "sum": 0.41456363629208065, "min": 0.41456363629208065}}, "EndTime": 1574385318.455448, "Dimensions": {"model": 27, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1574385318.45544}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.1209904872688603, "sum": 0.1209904872688603, "min": 0.1209904872688603}}, "EndTime": 1574385318.455487, "Dimensions": {"model": 28, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1574385318.455477}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.12103756559498115, "sum": 0.12103756559498115, "min": 0.12103756559498115}}, "EndTime": 1574385318.455521, "Dimensions": {"model": 29, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1574385318.45551}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.12123215968506809, "sum": 0.12123215968506809, "min": 0.12123215968506809}}, "EndTime": 1574385318.455552, "Dimensions": {"model": 30, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1574385318.455545}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.12081144119780086, "sum": 0.12081144119780086, "min": 0.12081144119780086}}, "EndTime": 1574385318.455591, "Dimensions": {"model": 31, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1574385318.45558}
#
# [11/22/2019 01:15:18 INFO 139974246963008] #quality_metric: host=algo-1, epoch=1, train binary_classification_cross_entropy_objective <loss>=0.402270134613
# [11/22/2019 01:15:18 INFO 139974246963008] #early_stopping_criteria_metric: host=algo-1, epoch=1, criteria=binary_classification_cross_entropy_objective, value=0.00147520893478
# [11/22/2019 01:15:18 INFO 139974246963008] Epoch 1: Loss improved. Updating best model
# [11/22/2019 01:15:18 INFO 139974246963008] #progress_metric: host=algo-1, completed 13 % of epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 11, "sum": 11.0, "min": 11}, "Number of Batches Since Last Reset": {"count": 1, "max": 11, "sum": 11.0, "min": 11}, "Number of Records Since Last Reset": {"count": 1, "max": 17995, "sum": 17995.0, "min": 17995}, "Total Batches Seen": {"count": 1, "max": 29, "sum": 29.0, "min": 29}, "Total Records Seen": {"count": 1, "max": 48583, "sum": 48583.0, "min": 48583}, "Max Records Seen Between Resets": {"count": 1, "max": 17995, "sum": 17995.0, "min": 17995}, "Reset Count": {"count": 1, "max": 4, "sum": 4.0, "min": 4}}, "EndTime": 1574385318.458098, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 

#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.10635613552261022, "sum": 0.10635613552261022, "min": 0.10635613552261022}}, "EndTime": 1574385318.660292, "Dimensions": {"model": 23, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1574385318.660282}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.29864794236544173, "sum": 0.29864794236544173, "min": 0.29864794236544173}}, "EndTime": 1574385318.660325, "Dimensions": {"model": 24, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1574385318.660318}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.2981493031203316, "sum": 0.2981493031203316, "min": 0.2981493031203316}}, "EndTime": 1574385318.660366, "Dimensions": {"model": 25, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1574385318.660358}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.2972421269737528, "sum": 0.2972421269737528, "min": 0.2972421269737528}}, "EndTime": 1574385318.660399, "Dimensions": {"model": 26, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1574385318.660388}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.2963807492470861, "sum": 0.2963807492470861, "min": 0.2963807492470861}}, "EndTime": 1574385318.660443, "Dimensions": {"model": 27, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1574385318.660432}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.12413345599850395, "sum": 0.12413345599850395, "min": 0.12413345599850395}}, "EndTime": 1574385318.660482, "Dimensions": {"model": 28, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1574385318.660475}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.12409320638337488, "sum": 0.12409320638337488, "min": 0.12409320638337488}}, "EndTime": 1574385318.660529, "Dimensions": {"model": 29, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1574385318.660517}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.12402295827733072, "sum": 0.12402295827733072, "min": 0.12402295827733072}}, "EndTime": 1574385318.660565, "Dimensions": {"model": 30, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1574385318.660558}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.1240164332153931, "sum": 0.1240164332153931, "min": 0.1240164332153931}}, "EndTime": 1574385318.660607, "Dimensions": {"model": 31, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1574385318.660599}
#
# [11/22/2019 01:15:18 INFO 139974246963008] #quality_metric: host=algo-1, epoch=2, train binary_classification_cross_entropy_objective <loss>=0.279465790389
# [11/22/2019 01:15:18 INFO 139974246963008] #early_stopping_criteria_metric: host=algo-1, epoch=2, criteria=binary_classification_cross_entropy_objective, value=0.000337342423423
# [11/22/2019 01:15:18 INFO 139974246963008] Epoch 2: Loss improved. Updating best model
# [11/22/2019 01:15:18 INFO 139974246963008] #progress_metric: host=algo-1, completed 20 % of epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 11, "sum": 11.0, "min": 11}, "Number of Batches Since Last Reset": {"count": 1, "max": 11, "sum": 11.0, "min": 11}, "Number of Records Since Last Reset": {"count": 1, "max": 17995, "sum": 17995.0, "min": 17995}, "Total Batches Seen": {"count": 1, "max": 40, "sum": 40.0, "min": 40}, "Total Records Seen": {"count": 1, "max": 66578, "sum": 66578.0, "min": 66578}, "Max Records Seen Between Resets": {"count": 1, "max": 17995, "sum": 17995.0, "min": 17995}, "Reset Count": {"count": 1, "max": 5, "sum": 5.0, "min": 5}}, "EndTime": 1574385318.662981, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1574385318.45833}
#
# [11/22/2019 01:15:18 INFO 139974246963008] #throughput_metric: host=algo-1, train throughput=87881.1947646 records/second
# [2019-11-22 01:15:18.887] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 9, "duration": 224, "num_examples": 11, "num_bytes": 1223660}
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.20180701043222798, "sum": 0.20180701043222798, "min": 0.20180701043222798}}, "EndTime": 1574385318.887965, "Dimensions": {"model": 0, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 3}, "StartTime": 1574385318.887881}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.20822388000657918, "sum": 0.20822388000657918, "min": 0.20822388000657918}}, "EndTime": 1574385318.888032, "Dimensions": {"model": 1, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 3}, "StartTime": 1574385318.888021}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.20982984762313697, "sum": 0.20982984762313697, "min": 0.20982984762313697}}, "EndTime": 1574385318.888064, "Dimensions": {"model": 2, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 3}, "StartTime": 1574385318.888057}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.20465801720356797, "sum": 0.20465801720356797, "min": 0.20465801720356797}}, "EndTime": 1574385318.888091, "Dimensions": {"model": 3, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 3}, "StartTime": 1574385318.888085}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.0002513376439923111, "sum": 0.0002513376439923111, "min": 0.0002513376439923111}}, "EndTime": 1574385318.888117, "Dimensions": {"model": 4, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 3}, "StartTime": 1574385318.888111}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.0002532661557528892, "sum": 0.0002532661557528892, "min": 0.0002532661557528892}}, "EndTime": 1574385318.888142, "Dimensions": {"model": 5, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 3}, "StartTime": 1574385318.888137}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0
"Dimensions": {"model": 28, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1574385321.318123}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.08779994165188343, "sum": 0.08779994165188343, "min": 0.08779994165188343}}, "EndTime": 1574385321.318153, "Dimensions": {"model": 29, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1574385321.318147}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.08779016126852157, "sum": 0.08779016126852157, "min": 0.08779016126852157}}, "EndTime": 1574385321.318184, "Dimensions": {"model": 30, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1574385321.318174}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.087794030249417, "sum": 0.087794030249417, "min": 0.087794030249417}}, "EndTime": 1574385321.318215, "Dimensions": {"model": 31, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1574385321.318204}
#
# [11/22/2019 01:15:21 INFO 139974246963008] #quality_metric: host=algo-1, epoch=14, train binary_classification_cross_entropy_objective <loss>=0.0376274420593
# [11/22/2019 01:15:21 INFO 139974246963008] #early_stopping_criteria_metric: host=algo-1, epoch=14, criteria=binary_classification_cross_entropy_objective, value=9.99416946835e-05
# [11/22/2019 01:15:21 INFO 139974246963008] Epoch 14: Loss improved. Updating best model
# [11/22/2019 01:15:21 INFO 139974246963008] #progress_metric: host=algo-1, completed 100 % of epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 11, "sum": 11.0, "min": 11}, "Number of Batches Since Last Reset": {"count": 1, "max": 11, "sum": 11.0, "min": 11}, "Number of Records Since Last Reset": {"count": 1, "max": 17995, "sum": 17995.0, "min": 17995}, "Total Batches Seen": {"count": 1, "max": 172, "sum": 172.0, "min": 172}, "Total Records Seen": {"count": 1, "max": 282518, "sum": 282518.0, "min": 282518}, "Max Records Seen Between Resets": {"count": 1, "max": 17995, "sum": 17995.0, "min": 17995}, "Reset Count": {"count": 1, "max": 17, "sum": 17.0, "min": 17}}, "EndTime": 1574385321.320541, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1574385321.129106}
#
# [11/22/2019 01:15:21 INFO 139974246963008] #throughput_metric: host=algo-1, train throughput=93945.1842521 records/second
# [11/22/2019 01:15:21 WARNING 139974246963008] wait_for_all_workers will not sync workers since the kv store is not running distributed
# [11/22/2019 01:15:21 WARNING 139974246963008] wait_for_all_workers will not sync workers since the kv store is not running distributed
# [2019-11-22 01:15:21.328] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 33, "duration": 7, "num_examples": 1, "num_bytes": 122332}
# [2019-11-22 01:15:21.401] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 36, "duration": 71, "num_examples": 11, "num_bytes": 1223660}
# [2019-11-22 01:15:21.460] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 38, "duration": 40, "num_examples": 11, "num_bytes": 1223660}
# [11/22/2019 01:15:21 INFO 139974246963008] #train_score (algo-1) : ('binary_classification_cross_entropy_objective', 9.904970260416955e-05)
# [11/22/2019 01:15:21 INFO 139974246963008] #train_score (algo-1) : ('binary_classification_accuracy', 0.999722145040289)
# [11/22/2019 01:15:21 INFO 139974246963008] #train_score (algo-1) : ('binary_f_1.000', 0.9921011058451816)
# [11/22/2019 01:15:21 INFO 139974246963008] #train_score (algo-1) : ('precision', 0.9843260188087775)
# [11/22/2019 01:15:21 INFO 139974246963008] #train_score (algo-1) : ('recall', 1.0)
# [11/22/2019 01:15:21 INFO 139974246963008] #quality_metric: host=algo-1, train binary_classification_cross_entropy_objective <loss>=9.90497026042e-05
# [11/22/2019 01:15:21 INFO 139974246963008] #quality_metric: host=algo-1, train binary_classification_accuracy <score>=0.99972214504
# [11/22/2019 01:15:21 INFO 139974246963008] #quality_metric: host=algo-1, train binary_f_1.000 <score>=0.992101105845
# [11/22/2019 01:15:21 INFO 139974246963008] #quality_metric: host=algo-1, train precision <score>=0.984326018809
# [11/22/2019 01:15:21 INFO 139974246963008] #quality_metric: host=algo-1, train recall <score>=1.0
# [11/22/2019 01:15:21 INFO 139974246963008] Best model found for hyperparameters: {"lr_scheduler_step": 100, "wd": 0.0001, "optimizer": "adam", "lr_scheduler_factor": 0.99, "l1": 0.0, "learning_rate": 0.1, "lr_scheduler_minimum_lr": 0.0001}
# [11/22/2019 01:15:21 INFO 139974246963008] Saved checkpoint to "/tmp/tmp5xa6nv/mx-mod-0000.params"
# [2019-11-22 01:15:21.464] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/test", "epoch": 0, "duration": 3536, "num_examples": 1, "num_bytes": 122332}
# [2019-11-22 01:15:21.471] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/test", "epoch": 1, "duration": 7, "num_examples": 2, "num_bytes": 136000}
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 2, "sum": 2.0, "min": 2}, "Number of Batches Since Last Reset": {"count": 1, "max": 2, "sum": 2.0, "min": 2}, "Number of Records Since Last Reset": {"count": 1, "max": 2000, "sum": 2000.0, "min": 2000}, "Total Batches Seen": {"count": 1, "max": 2, "sum": 2.0, "min": 2}, "Total Records Seen": {"count": 1, "max": 2000, "sum": 2000.0, "min": 2000}, "Max Records Seen Between Resets": {"count": 1, "max": 2000, "sum": 2000.0, "min": 2000}, "Reset Count": {"count": 1, "max": 1, "sum": 1.0, "min": 1}}, "EndTime": 1574385321.47183, "Dimensions": {"Host": "algo-1", "Meta": "test_data_iter", "Operation": "training", "Algorithm": "Linear Learner"}, "StartTime": 1574385321.464411}
#
# [11/22/2019 01:15:21 INFO 139974246963008] #test_score (algo-1) : ('binary_classification_cross_entropy_objective', 0.00011240942962467671)
# [11/22/2019 01:15:21 INFO 139974246963008] #test_score (algo-1) : ('binary_classification_accuracy', 1.0)
# [11/22/2019 01:15:21 INFO 139974246963008] #test_score (algo-1) : ('binary_f_1.000', 1.0)
# [11/22/2019 01:15:21 INFO 139974246963008] #test_score (algo-1) : ('precision', 1.0)
# [11/22/2019 01:15:21 INFO 139974246963008] #test_score (algo-1) : ('recall', 1.0)
# [11/22/2019 01:15:21 INFO 139974246963008] #quality_metric: host=algo-1, test binary_classification_cross_entropy_objective <loss>=0.000112409429625
# [11/22/2019 01:15:21 INFO 139974246963008] #quality_metric: host=algo-1, test binary_classification_accuracy <score>=1.0
# [11/22/2019 01:15:21 INFO 139974246963008] #quality_metric: host=algo-1, test binary_f_1.000 <score>=1.0
# [11/22/2019 01:15:21 INFO 139974246963008] #quality_metric: host=algo-1, test precision <score>=1.0
# [11/22/2019 01:15:21 INFO 139974246963008] #quality_metric: host=algo-1, test recall <score>=1.0
# #metrics {"Metrics": {"totaltime": {"count": 1, "max": 3614.6979331970215, "sum": 3614.6979331970215, "min": 3614.6979331970215}, "finalize.time": {"count": 1, "max": 140.81096649169922, "sum": 140.81096649169922, "min": 140.81096649169922}, "initialize.time": {"count": 1, "max": 120.69201469421387, "sum": 120.69201469421387, "min": 120.69201469421387}, "check_early_stopping.time": {"count": 15, "max": 1.0221004486083984, "sum": 11.506795883178711, "min": 0.6449222564697266}, "setuptime": {"count": 1, "max": 20.061969757080078, "sum": 20.061969757080078, "min": 20.061969757080078}, "update.time": {"count": 15, "max": 283.71596336364746, "sum": 3261.826992034912, "min": 180.49097061157227}, "epochs": {"count": 1, "max": 15, "sum": 15.0, "min": 15}}, "EndTime": 1574385321.475384, "Dimensions": {"Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner"}, "StartTime": 1574385317.92335}
#
# Training seconds: 36
# Billable seconds: 36

# %% [markdown]
# Notice that we mentioned a test set in the training job. When a test set is provided the training job doesn't just produce a model but also applies it to the test set and reports the accuracy. In the logs you can view the accuracy of the model on the test set.

# %% [markdown]
# ## Conclusion
#
# We now have a trained model living in S3. Instead of creating a SageMaker Endpoint, we will use Lambda to make inferences against the model.
#
# If you want to test the model using a SageMaker Endpoint before moving on, check out our documentation:
# https://docs.aws.amazon.com/sagemaker/latest/dg/ex1-deploy-model.html#ex1-deploy-model-boto
#
# At this point you can close out of the SageMaker notebook and continue with the workshop instructions.
